# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from datetime import date, timedelta

import mechafil.data as mecha_data
import mechafil.data_spacescope as data_spacescope
from mechafil.data import get_historical_network_stats, get_sector_expiration_stats, setup_spacescope

import mechafil.power as np_power
import mechafil_jax.power as jax_power

import matplotlib.pyplot as plt

# %%
import pickle

# %%
with open('/Users/kiran/code/mechafil-jax/test/cil_jax.pkl', 'rb') as f:
    z = pickle.load(f)

# %%
cil_np = z['np']
cil_jax = z['jax']

# %%
plt.figure(figsize=(8,9))

plt.subplot(4,2,1)
plt.plot(cil_np['network_gas_burn'], label='MechaFIL')
plt.plot(cil_jax['network_gas_burn'], label='JAX', linestyle=':')
plt.title('Gas Burn')
plt.legend()

plt.subplot(4,2,2)
plt.plot(cil_np['day_locked_pledge'])
plt.plot(cil_jax['day_locked_pledge'], linestyle=':')
plt.title('Day Locked Pledge')

plt.subplot(4,2,3)
plt.plot(cil_np['day_renewed_pledge'])
plt.plot(cil_jax['day_renewed_pledge'], linestyle=':')
plt.title('Day Renewed Pledge')

plt.subplot(4,2,4)
plt.plot(cil_np['network_locked_pledge'])
plt.plot(cil_jax['network_locked_pledge'], linestyle=':')
plt.title('Network Locked Pledge')

plt.subplot(4,2,5)
plt.plot(cil_np['day_network_reward'])
plt.plot(cil_jax['day_network_reward'], linestyle=':')
plt.title('Day Network Reward')

plt.subplot(4,2,6)
plt.plot(cil_np['cum_network_reward'])
plt.plot(cil_jax['cum_network_reward'], linestyle=':')
plt.title('Cum Network Reward')

plt.subplot(4,2,7)
plt.plot(cil_np['circ_supply'])
plt.plot(cil_jax['circ_supply'], linestyle=':')
plt.title('CS')

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">
